# %%
import matplotlib.pyplot as plt
import numpy as np

# Seleccionar solo las columnas numéricas para el histograma
df_numeric = df.select_dtypes(include=np.number)

# Crear histogramas para cada columna
df_numeric.hist(figsize=(20, 15))
plt.suptitle("Histogramas de todas las variables numéricas", fontsize=20)
plt.tight_layout(rect=[0, 0.03, 1, 0.97]) # Ajustar el layout para evitar que el título se solape
plt.show()

# %%
# ============================================
# MATRIZ DE CORRELACIÓN SPEARMAN (M1 y M4) - SIN NÚMEROS
# ============================================

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# =======================
# 0. Cargar datos
# =======================
df = pd.read_csv("/content/DATAMAT012025.csv")

# =======================
# 1. Filtrar solo M1 y M4
# =======================
cols = [col for col in df.columns if col.startswith("M3") or col.startswith("M4")]
df_m1_m4 = df[cols]

# =======================
# 2. Calcular correlación Spearman
# =======================
corr_spearman = df_m1_m4.corr(method="spearman")

# =======================
# 3. Visualización con heatmap (sin anotaciones)
# =======================
plt.figure(figsize=(12,8))
sns.heatmap(
    corr_spearman,
    annot=False,  # 👈 Quita los números
    cmap="coolwarm",
    cbar=True,
    square=True,
    linewidths=.5
)
plt.title("Matriz de Correlación Spearman (M3 y M4)", fontsize=16)
plt.show()

# =======================
# 4. Guardar resultados en CSV
# =======================
corr_spearman.to_csv("/content/correlacion_spearman_M1_M4.csv")
print("✅ Matriz de correlación (M1 y M4) guardada en correlacion_spearman_M1_M4.csv")
# Out:
# ✅ Matriz de correlación (M1 y M4) guardada en correlacion_spearman_M1_M4.csv

# %%
# ============================================
# MATRIZ DE CORRELACIÓN SPEARMAN (M1 y M4) - SIN NÚMEROS
# ============================================

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# =======================
# 0. Cargar datos
# =======================
df = pd.read_csv("/content/DATAMAT012025.csv")

# =======================
# 1. Filtrar solo M1 y M4
# =======================
cols = [col for col in df.columns if col.startswith("M1") or col.startswith("M2")]
df_m1_m4 = df[cols]

# =======================
# 2. Calcular correlación Spearman
# =======================
corr_spearman = df_m1_m4.corr(method="spearman")

# =======================
# 3. Visualización con heatmap (sin anotaciones)
# =======================
plt.figure(figsize=(12,8))
sns.heatmap(
    corr_spearman,
    annot=False,  # 👈 Quita los números
    cmap="coolwarm",
    cbar=True,
    square=True,
    linewidths=.5
)
plt.title("Matriz de Correlación Spearman (M1 y M2)", fontsize=16)
plt.show()

# =======================
# 4. Guardar resultados en CSV
# =======================
corr_spearman.to_csv("/content/correlacion_spearman_M1_M4.csv")
print("✅ Matriz de correlación (M1 y M4) guardada en correlacion_spearman_M1_M4.csv")
# Out:
# ✅ Matriz de correlación (M1 y M4) guardada en correlacion_spearman_M1_M4.csv

# %%
# ============================================
# MATRIZ DE CORRELACIÓN SPEARMAN (M1 y M4) - SIN NÚMEROS
# ============================================

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# =======================
# 0. Cargar datos
# =======================
df = pd.read_csv("/content/DATAMAT012025.csv")

# =======================
# 1. Filtrar solo M1 y M4
# =======================
cols = [col for col in df.columns if col.startswith("M1") or col.startswith("M3")]
df_m1_m4 = df[cols]

# =======================
# 2. Calcular correlación Spearman
# =======================
corr_spearman = df_m1_m4.corr(method="spearman")

# =======================
# 3. Visualización con heatmap (sin anotaciones)
# =======================
plt.figure(figsize=(12,8))
sns.heatmap(
    corr_spearman,
    annot=False,  # 👈 Quita los números
    cmap="coolwarm",
    cbar=True,
    square=True,
    linewidths=.5
)
plt.title("Matriz de Correlación Spearman (M1 y M3)", fontsize=16)
plt.show()

# =======================
# 4. Guardar resultados en CSV
# =======================
corr_spearman.to_csv("/content/correlacion_spearman_M1_M4.csv")
print("✅ Matriz de correlación (M1 y M4) guardada en correlacion_spearman_M1_M4.csv")
# Out:
# ✅ Matriz de correlación (M1 y M4) guardada en correlacion_spearman_M1_M4.csv

# %%
# ============================================
# MATRIZ DE CORRELACIÓN SPEARMAN (M1 y M4) - SIN NÚMEROS
# ============================================

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# =======================
# 0. Cargar datos
# =======================
df = pd.read_csv("/content/DATAMAT012025.csv")

# =======================
# 1. Filtrar solo M1 y M4
# =======================
cols = [col for col in df.columns if col.startswith("M1") or col.startswith("M4")]
df_m1_m4 = df[cols]

# =======================
# 2. Calcular correlación Spearman
# =======================
corr_spearman = df_m1_m4.corr(method="spearman")

# =======================
# 3. Visualización con heatmap (sin anotaciones)
# =======================
plt.figure(figsize=(12,8))
sns.heatmap(
    corr_spearman,
    annot=False,  # 👈 Quita los números
    cmap="coolwarm",
    cbar=True,
    square=True,
    linewidths=.5
)
plt.title("Matriz de Correlación Spearman (M1 y M4)", fontsize=16)
plt.show()

# =======================
# 4. Guardar resultados en CSV
# =======================
corr_spearman.to_csv("/content/correlacion_spearman_M1_M4.csv")
print("✅ Matriz de correlación (M1 y M4) guardada en correlacion_spearman_M1_M4.csv")
# Out:
# ✅ Matriz de correlación (M1 y M4) guardada en correlacion_spearman_M1_M4.csv

# %%
# ============================================
# MATRIZ DE CORRELACIÓN SPEARMAN (M1 y M4) - SIN NÚMEROS
# ============================================

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# =======================
# 0. Cargar datos
# =======================
df = pd.read_csv("/content/DATAMAT012025.csv")

# =======================
# 1. Filtrar solo M1 y M4
# =======================
cols = [col for col in df.columns if col.startswith("M2") or col.startswith("M4")]
df_m1_m4 = df[cols]

# =======================
# 2. Calcular correlación Spearman
# =======================
corr_spearman = df_m1_m4.corr(method="spearman")

# =======================
# 3. Visualización con heatmap (sin anotaciones)
# =======================
plt.figure(figsize=(12,8))
sns.heatmap(
    corr_spearman,
    annot=False,  # 👈 Quita los números
    cmap="coolwarm",
    cbar=True,
    square=True,
    linewidths=.5
)
plt.title("Matriz de Correlación Spearman (M2 y M3)", fontsize=16)
plt.show()

# =======================
# 4. Guardar resultados en CSV
# =======================
corr_spearman.to_csv("/content/correlacion_spearman_M1_M4.csv")
print("✅ Matriz de correlación (M1 y M4) guardada en correlacion_spearman_M1_M4.csv")
# Out:
# ✅ Matriz de correlación (M1 y M4) guardada en correlacion_spearman_M1_M4.csv

# %%
# --- Librerías ---
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# --- Cargar el dataset ---
# Asegúrate de haber subido tu archivo a Colab
df = pd.read_csv('/content/DATAMAT012025.csv')

# --- Definir variables predictoras y objetivo ---
# Ajusta el nombre del objetivo según lo que quieras predecir
y = df['M1_B1_2024']
X = df.drop(columns=['M1_B1_2024'])

# --- Calcular la matriz de correlación (Spearman) ---
corr_matrix = X.corr(method='spearman')

# --- Visualizar la matriz como heatmap ---
plt.figure(figsize=(16, 12))
sns.heatmap(corr_matrix, cmap='coolwarm', center=0)
plt.title("Matriz de Correlación de Spearman (Todas las Variables)", fontsize=16)
plt.show()

# --- Correlaciones con la variable objetivo ---
correlaciones_objetivo = X.corrwith(y, method='spearman').sort_values(ascending=False)

# Mostrar correlaciones en orden
print("=== Correlaciones con el objetivo (Spearman) ===")
print(correlaciones_objetivo)

# --- Filtrar las más relevantes (|corr| > 0.1) ---
variables_relevantes = correlaciones_objetivo[correlaciones_objetivo.abs() > 0.1]
print("\n=== Variables con correlación > 0.1 o < -0.1 ===")
print(variables_relevantes)
# Out:
# === Correlaciones con el objetivo (Spearman) ===
# M1_B2_2024    1.000000
# M1_B4_2024    1.000000
# M1_B3_2024    1.000000
# M3_B3_2024    0.609122
# M3_B4_2024    0.609122
#                 ...
# M4_B2_2023    0.134114
# M1_B2_2025   -0.180552
# M2_B2_2025   -0.180552
# M3_B2_2025   -0.180552
# M4_B2_2025   -0.180552
# Length: 71, dtype: float64
#
# === Variables con correlación > 0.1 o < -0.1 ===
# M1_B2_2024    1.000000
# M1_B4_2024    1.000000
# M1_B3_2024    1.000000
# M3_B3_2024    0.609122
# M3_B4_2024    0.609122
#                 ...
# M4_B2_2023    0.134114
# M1_B2_2025   -0.180552
# M2_B2_2025   -0.180552
# M3_B2_2025   -0.180552
# M4_B2_2025   -0.180552
# Length: 71, dtype: float64

# %% [markdown]
# Perfecto 🙌, te preparo un código generalizado que aplica la lógica definida:
#
# Usa regresión logística con SMOTE.
#
# Si el target es B1, entrena con años previos.
#
# Si el target es B2, entrena con años previos + B1 del 2025.
#
# Features según la estrategia:
#
# M1 → M1 y M3
#
# M2 → M1, M2 y M4
#
# M3 → M1 y M3
#
# M4 → M1, M2 y M4
#
# Se puede extender fácilmente a B3 y B4 en el futuro.

# %%
VARIABLES IMPORTANTES REGRESIÓN LOGISTICA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Asegurarse de que 'model' y 'X' están definidos del paso anterior (si se ejecutó la celda 'cEyg3iqbJRSt_fix_code')
# Si no se ejecutó, se recomienda ejecutarla primero para inicializar estas variables.

# Obtener los coeficientes del modelo de regresión logística
# Para un clasificador binario, model.coef_ es un array 2D, tomamos la primera fila [0]
coefficients = model.coef_[0]

# Obtener los nombres de las características
feature_names = X.columns

# Crear un DataFrame para visualizar las importancias
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient': coefficients,
    'Absolute_Coefficient': np.abs(coefficients)
})

# Ordenar por la importancia absoluta de los coeficientes
feature_importance_df = feature_importance_df.sort_values(by='Absolute_Coefficient', ascending=False)

print("\nImportancia de Variables (Regresión Logística - M1-B1):")
print(feature_importance_df)

# Visualización de la importancia de las variables
plt.figure(figsize=(10, 8))
sns.barplot(x='Absolute_Coefficient', y='Feature', data=feature_importance_df.head(15), palette='viridis')
plt.title('Top 15 Variables Más Importantes (Regresión Logística - M1-B1)')
plt.xlabel('Valor Absoluto del Coeficiente Normalizado')
plt.ylabel('Variable')
plt.tight_layout()
plt.show()
# Out:
# Importancia de Variables (Regresión Logística - M1-B1):
#        Feature  Coefficient  Absolute_Coefficient
# 3   M1_B2_2022     0.721785              0.721785
# 18  M3_B3_2022     0.575134              0.575134
# 21  M3_B4_2022     0.367330              0.367330
# 17  M3_B2_2024     0.366640              0.366640
# 14  M3_B1_2024     0.189887              0.189887
# 6   M1_B3_2022    -0.160388              0.160388
# 23  M3_B4_2024     0.123220              0.123220
# 13  M3_B1_2023     0.122142              0.122142
# 4   M1_B2_2023    -0.110006              0.110006
# 22  M3_B4_2023     0.104063              0.104063
# 20  M3_B3_2024     0.100003              0.100003
# 16  M3_B2_2023     0.089115              0.089115
# 19  M3_B3_2023     0.031457              0.031457
# 10  M1_B4_2023    -0.024277              0.024277
# 7   M1_B3_2023    -0.001418              0.001418
# 1   M1_B1_2023    -0.000351              0.000351
# 5   M1_B2_2024     0.000000              0.000000
# ...

# %% [markdown]
# Regresión logistica 14-11

# %%
# ============================================
# REGRESIÓN LOGÍSTICA - PREDICCIÓN M1–M4 (B1–B2)
# Solo datos hasta 2024 - Código Corregido
# ============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    classification_report, f1_score, precision_score, recall_score,
    accuracy_score, confusion_matrix, ConfusionMatrixDisplay
)
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

# =======================
# 0. Cargar datos
# =======================
df = pd.read_csv("/content/DATAMAT012025.csv")

# =======================
# 1. Definir estrategia correcta de features por competencia
# =======================
estrategia = {
    "M1": ["M1"],
    "M2": ["M1", "M2"],
    "M3": ["M1", "M2", "M3"],
    "M4": ["M1", "M2", "M3", "M4"]
}

bimestres = ["B1", "B2", "B3", "B4"]

# =======================
# 2. Pipeline (normalización + SMOTE + RL)
# =======================
pipe = ImbPipeline([
    ('scaler', StandardScaler()),
    ('smote', SMOTE(random_state=42)),
    ('clf', LogisticRegression(solver='liblinear', max_iter=1000))
])

param_grid = {
    'clf__C': [0.01, 0.1, 1, 10],
    'clf__penalty': ['l1', 'l2']
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# =======================
# 3. Loop solo hasta 2024
# =======================
resultados = []

for comp, feats in estrategia.items():
    for bim in ["B1", "B2"]:  # solo B1 y B2
        target_2024 = f"{comp}_{bim}_2024"

        if target_2024 not in df.columns:
            continue

        print("="*60)
        print(f"   {comp} - {bim} (SOLO HASTA 2024)")
        print("="*60)

        # ---------------- FEATURES ----------------
        features = [f"{f}_{b}" for f in feats for b in bimestres]

        # Entrenamiento con 2021–2023
        train_cols = [f"{feat}_{year}" for feat in features for year in ["2021", "2022", "2023"]]
        X_train = df[train_cols]
        y_train = df[target_2024]  # solo 2024 como etiqueta

        # ---------------- ENTRENAMIENTO + GRID SEARCH ----------------
        grid = GridSearchCV(
            pipe, param_grid, scoring='f1', cv=cv, n_jobs=-1
        )
        grid.fit(X_train, y_train)

        # ---------------- OPTIMIZACIÓN DE UMBRAL ----------------
        y_proba = grid.predict_proba(X_train)[:, 1]
        thresholds = np.linspace(0, 1, 101)
        f1_scores = [f1_score(y_train, (y_proba >= t).astype(int)) for t in thresholds]
        best_t = thresholds[np.argmax(f1_scores)]

        print("Mejores hiperparámetros:", grid.best_params_)
        print("Umbral óptimo (máx F1):", round(best_t, 2))
        print("\nMétricas 2024:")
        print(classification_report(y_train, (y_proba >= best_t).astype(int)))

        # ---------------- MATRIZ DE CONFUSIÓN ----------------
        y_pred = (y_proba >= best_t).astype(int)
        cm = confusion_matrix(y_train, y_pred)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1])
        disp.plot(cmap=plt.cm.Blues, values_format="d")
        plt.title(f"{comp}-{bim} | Matriz Confusión 2024")
        plt.show()

        # ---------------- CALCULO REAL DE F1 ----------------
        f1 = f1_score(y_train, y_pred)

        # ---------------- GUARDAR RESULTADOS ----------------
        resultados.append({
            "Competencia": comp,
            "Bimestre": bim,
            "Mejores_Params": grid.best_params_,
            "Umbral": round(best_t, 2),
            "Accuracy_2024": round(accuracy_score(y_train, y_pred), 4),
            "Precision_2024": round(precision_score(y_train, y_pred), 4),
            "Recall_2024": round(recall_score(y_train, y_pred), 4),
            "F1_2024": round(f1, 4),
            "Matriz_Confusion": cm.tolist()
        })

# =======================
# 4. Resumen final
# =======================
df_resultados = pd.DataFrame(resultados)
print("\n===== RESUMEN DE RESULTADOS 2024 =====")
print(df_resultados.to_string(index=False))
# Out:
# ...
#    M1 - B1 (SOLO HASTA 2024)
# ...
# Mejores hiperparámetros: {'clf__C': 0.01, 'clf__penalty': 'l2'}
# Umbral óptimo (máx F1): 0.39
#
# Métricas 2024:
#               precision    recall  f1-score   support
#
#            0       0.68      0.53      0.59        40
#            1       0.68      0.80      0.74        51
#
#     accuracy                           0.68        91
#    macro avg       0.68      0.66      0.67        91
# weighted avg       0.68      0.68      0.67        91
# ...
#    M1 - B2 (SOLO HASTA 2024)
# ...
# Mejores hiperparámetros: {'clf__C': 0.01, 'clf__penalty': 'l2'}
# Umbral óptimo (máx F1): 0.39
#
# Métricas 2024:
#               precision    recall  f1-score   support
#
#            0       0.68      0.53      0.59        40
#            1       0.68      0.80      0.74        51
#
#     accuracy                           0.68        91
#    macro avg       0.68      0.66      0.67        91
# weighted avg       0.68      0.68      0.67        91
# ...

# %% [markdown]
# REGRESIÓN LOGÍSTICA CON B3 Y B4

# %%
# ============================================
# REGRESIÓN LOGÍSTICA - PREDICCIÓN M1–M4 (B3–B4) PARA 2025 + MATRICES DE CONFUSIÓN
# ============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    classification_report, f1_score, precision_score, recall_score,
    accuracy_score, confusion_matrix, ConfusionMatrixDisplay
)
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

# =======================
# 0. Cargar datos
# =======================
df = pd.read_csv("/content/DATAMAT012025.csv")

# =======================
# 1. Estrategia de features
# =======================
estrategia = {
    "M1": ["M1", "M3"],
    "M2": ["M1", "M2", "M4"],
    "M3": ["M1", "M3"],
    "M4": ["M1", "M2", "M4"]
}
bimestres = ["B1", "B2", "B3", "B4"]  # para construir features históricos

# =======================
# 2. Pipeline de regresión logística
# =======================
pipe = ImbPipeline([
    ('scaler', StandardScaler()),
    ('smote', SMOTE(random_state=42)),
    ('clf', LogisticRegression(solver='liblinear', max_iter=1000))
])

param_grid = {
    'clf__C': [0.01, 0.1, 1, 10],
    'clf__penalty': ['l1', 'l2']
}
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# =======================
# 3. Loop de predicción B3 y B4
# =======================
resultados = []

for comp, feats in estrategia.items():
    for bim in ["B3", "B4"]:
        target_2024 = f"{comp}_{bim}_2024"

        if target_2024 not in df.columns:
            print(f"⚠️ No se encontró columna {target_2024}, se omite.")
            continue

        print("=" * 60)
        print(f"   {comp} - {bim}")
        print("=" * 60)

        # Construcción de features históricos (hasta el bimestre anterior)
        idx_bim = int(bim[1])
        features_historicas = [f"{f}_B{i}" for f in feats for i in range(1, idx_bim + 1)]

        # ---------------- ENTRENAMIENTO 2024 ----------------
        X_train_2024 = df[[f"{feat}_{year}" for feat in features_historicas for year in ["2021", "2022", "2023"]]]
        y_train_2024 = df[target_2024]

        grid_2024 = GridSearchCV(pipe, param_grid, scoring='f1', cv=cv, n_jobs=-1)
        grid_2024.fit(X_train_2024, y_train_2024)

        # Mejor umbral en 2024
        y_proba_2024 = grid_2024.predict_proba(X_train_2024)[:, 1]
        thresholds = np.linspace(0, 1, 101)
        f1_scores = [f1_score(y_train_2024, (y_proba_2024 >= t).astype(int)) for t in thresholds]
        best_t = thresholds[np.argmax(f1_scores)]

        print("Mejores hiperparámetros:", grid_2024.best_params_)
        print("Umbral óptimo (máx F1 en 2024):", round(best_t, 2))
        print("\nMétricas 2024:")
        y_pred_2024 = (y_proba_2024 >= best_t).astype(int)
        print(classification_report(y_train_2024, y_pred_2024))

        # === MATRIZ DE CONFUSIÓN ===
        cm = confusion_matrix(y_train_2024, y_pred_2024)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
        disp.plot(cmap='Blues', values_format='d')
        plt.title(f"Matriz de confusión {comp}-{bim}-2024")
        plt.show()

        print(f"Matriz de confusión {comp}-{bim}-2024:\n{cm}\n")

        # ---------------- PREDICCIÓN 2025 ----------------
        X_pred_2025 = df[[f"{feat}_{year}" for feat in features_historicas for year in ["2022", "2023", "2024"]]].copy()

        # Renombrar columnas temporalmente para coincidir con X_train_2024
        rename_dict = {}
        for feat in features_historicas:
            rename_dict[f"{feat}_2022"] = f"{feat}_2021"
            rename_dict[f"{feat}_2023"] = f"{feat}_2022"
            rename_dict[f"{feat}_2024"] = f"{feat}_2023"
        X_pred_2025.rename(columns=rename_dict, inplace=True)

        y_proba_2025 = grid_2024.predict_proba(X_pred_2025)[:, 1]
        y_pred_2025 = (y_proba_2025 >= best_t).astype(int)
        df[f"{comp}_{bim}_2025"] = y_pred_2025

        # Métricas sobre 2024 (entrenamiento)
        precision = precision_score(y_train_2024, y_pred_2024)
        recall = recall_score(y_train_2024, y_pred_2024)
        f1 = f1_score(y_train_2024, y_pred_2024)
        acc = accuracy_score(y_train_2024, y_pred_2024)

        resultados.append({
            "Competencia": comp,
            "Bimestre": bim,
            "Mejores_Params": grid_2024.best_params_,
            "Umbral": round(best_t, 2),
            "Accuracy_2024": round(acc, 4),
            "Precision_2024": round(precision, 4),
            "Recall_2024": round(recall, 4),
            "F1_2024": round(f1, 4),
            "MatrizConfusion": cm.tolist()
        })

        print(f"✅ Predicción {comp}-{bim}-2025 generada.\n")

# =======================
# 4. Resumen final
# =======================
df_resultados = pd.DataFrame(resultados)
print("\n===== RESUMEN DE RESULTADOS =====")
print(df_resultados)

# Guardar resultados y predicciones
df.to_csv("/content/DATAMAT012025_RegLog_Predicciones2025.csv", index=False)
df_resultados.to_csv("/content/Resultados_RegLog_B3B4.csv", index=False)
# Out:
# ...
#    M1 - B3
# ...
# Mejores hiperparámetros: {'clf__C': 0.1, 'clf__penalty': 'l1'}
# Umbral óptimo (máx F1 en 2024): 0.4
#
# Métricas 2024:
#               precision    recall  f1-score   support
#
#            0       0.74      0.50      0.60        40
#            1       0.69      0.86      0.77        51
#
#     accuracy                           0.70        91
#    macro avg       0.71      0.68      0.68        91
# weighted avg       0.71      0.70      0.69        91
# Matriz de confusión M1-B3-2024:
# [[20 20]
#  [ 7 44]]
#
# ✅ Predicción M1-B3-2025 generada.
#
# ...
#    M1 - B4
# ...
# Mejores hiperparámetros: {'clf__C': 0.1, 'clf__penalty': 'l1'}
# Umbral óptimo (máx F1 en 2024): 0.4
#
# Métricas 2024:
#               precision    recall  f1-score   support
#
#            0       0.74      0.50      0.60        40
#            1       0.69      0.86      0.77        51
#
#     accuracy                           0.70        91
#    macro avg       0.71      0.68      0.68        91
# ...

# %%
SVM B1 Y B2 2024

# %%
# ============================================
# SVM - PREDICCIÓN CON DATOS HASTA 2024
# Competencias M1–M4 | Bimestres B1–B2
# ============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.svm import SVC
from sklearn.metrics import (
    classification_report, f1_score, precision_score, recall_score,
    accuracy_score, confusion_matrix, ConfusionMatrixDisplay
)
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

# =======================
# 0. Cargar datos
# =======================
df = pd.read_csv("/content/DATAMAT012025.csv")

# =======================
# 1. Definir competencias y features (CORREGIDO)
# =======================
bimestres = ["B1", "B2", "B3", "B4"]

# LÓGICA CORRECTA (igual que LightGBM)
features_dict = {
    "M1": ["M1"],
    "M2": ["M1", "M2"],
    "M3": ["M1", "M2", "M3"],
    "M4": ["M1", "M2", "M3", "M4"]
}

# =======================
# 2. Configuración SVM
# =======================
pipe = ImbPipeline([
    ('scaler', StandardScaler()),
    ('smote', SMOTE(random_state=42)),
    ('clf', SVC(probability=True))
])

param_grid = {
    'clf__kernel': ['linear', 'rbf', 'poly'],
    'clf__C': [0.1, 1, 10],
    'clf__gamma': ['scale', 'auto']
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

resultados = []

# =======================
# 3. Bucle por competencias y bimestres (solo hasta 2024)
# =======================
for comp, feats in features_dict.items():
    for bim in ["B1", "B2"]:

        target_2024 = f"{comp}_{bim}_2024"

        if target_2024 not in df.columns:
            continue

        print("="*60)
        print(f"     {comp} - {bim}  (SOLO HASTA 2024)")
        print("="*60)

        # Armar features correctos
        feats_all = [f"{c}_{b}" for c in feats for b in bimestres]

        # Entrenamiento con 2021–2023
        train_2024 = [f"{f}_{y}" for f in feats_all for y in ["2021", "2022", "2023"]]
        X_train = df[train_2024]
        y_train = df[target_2024]

        # =======================
        # 3.1 Grid Search + entrenamiento
        # =======================
        grid = GridSearchCV(pipe, param_grid, scoring='f1', cv=cv, n_jobs=-1)
        grid.fit(X_train, y_train)

        y_proba = grid.predict_proba(X_train)[:, 1]

        # =======================
        # 3.2 Optimizar umbral en 2024
        # =======================
        thresholds = np.linspace(0, 1, 101)
        f1_scores = [f1_score(y_train, (y_proba >= t).astype(int)) for t in thresholds]
        best_t = thresholds[np.argmax(f1_scores)]

        print("Mejores hiperparámetros:", grid.best_params_)
        print("Umbral óptimo (máx F1):", round(best_t, 2))

        # =======================
        # 3.3 Métricas finales 2024
        # =======================
        y_pred = (y_proba >= best_t).astype(int)

        print("\nReporte de clasificación 2024:")
        print(classification_report(y_train, y_pred))

        acc = accuracy_score(y_train, y_pred)
        prec = precision_score(y_train, y_pred)
        rec = recall_score(y_train, y_pred)
        f1 = f1_score(y_train, y_pred)

        print(f"Aciertos: {np.sum(y_pred == y_train)}, Fallos: {np.sum(y_pred != y_train)}, Exactitud: {acc:.2%}")

        # =======================
        # 3.4 Matriz de confusión
        # =======================
        cm = confusion_matrix(y_train, y_pred)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
        disp.plot(cmap=plt.cm.Blues, values_format="d")
        plt.title(f"{comp}-{bim} | Matriz Confusión 2024 (SVM)")
        plt.show()

        # Guardar resultados
        resultados.append({
            "Competencia": comp,
            "Bimestre": bim,
            "Mejores_Params": grid.best_params_,
            "Umbral": round(best_t, 2),
            "Accuracy_2024": round(acc, 4),
            "Precision_2024": round(prec, 4),
            "Recall_2024": round(rec, 4),
            "F1_2024": round(f1, 4),
            "Aciertos": int(np.sum(y_pred == y_train)),
            "Fallos": int(np.sum(y_pred != y_train)),
            "Matriz_Confusion": cm.tolist()
        })

# =======================
# 4. Tabla resumen
# =======================
df_resultados = pd.DataFrame(resultados)
print("\n===== RESUMEN FINAL SOLO 2024 =====")
print(df_resultados.to_string(index=False))
# Out:
# ...
#      M1 - B1  (SOLO HASTA 2024)
# ...
# Mejores hiperparámetros: {'clf__C': 0.1, 'clf__gamma': 'scale', 'clf__kernel': 'linear'}
# Umbral óptimo (máx F1): 0.32
#
# Reporte de clasificación 2024:
#               precision    recall  f1-score   support
#
#            0       0.68      0.53      0.59        40
#            1       0.68      0.80      0.74        51
#
#     accuracy                           0.68        91
#    macro avg       0.68      0.66      0.67        91
# weighted avg       0.68      0.68      0.67        91
#
# Aciertos: 62, Fallos: 29, Exactitud: 68.13%
# ...
#      M1 - B2  (SOLO HASTA 2024)
# ...
# Mejores hiperparámetros: {'clf__C': 0.1, 'clf__gamma': 'scale', 'clf__kernel': 'linear'}
# Umbral óptimo (máx F1): 0.31
#
# Reporte de clasificación 2024:
#               precision    recall  f1-score   support
#
#            0       0.68      0.53      0.59        40
#            1       0.68      0.80      0.74        51
#
#     accuracy                           0.68        91
# ...

# %% [markdown]
# SVM B3 B4

# %%
# ============================================
# SVM - PREDICCIÓN TEMPORAL M1–M4 (B3–B4) + MATRICES DE CONFUSIÓN
# ============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.svm import SVC
from sklearn.metrics import (
    classification_report, f1_score, precision_score, recall_score,
    accuracy_score, confusion_matrix, ConfusionMatrixDisplay
)
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

# =======================
# 0. Cargar datos
# =======================
df = pd.read_csv("/content/DATAMAT012025.csv")

# =======================
# 1. Competencias y bimestres
# =======================
bimestres = ["B1", "B2", "B3", "B4"]
features_dict = {
    "M1": ["M1", "M3"],
    "M2": ["M1", "M2"],
    "M3": ["M1", "M2", "M3"],
    "M4": ["M1", "M2", "M3", "M4"]
}

# =======================
# 2. Pipeline SVM
# =======================
pipe = ImbPipeline([
    ('scaler', StandardScaler()),
    ('smote', SMOTE(random_state=42)),
    ('clf', SVC(probability=True))
])

param_grid = {
    'clf__kernel': ['linear', 'rbf', 'poly'],
    'clf__C': [0.1, 1, 10],
    'clf__gamma': ['scale', 'auto']
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# =======================
# 3. Loop B3 y B4
# =======================
resultados = []

for comp, feats in features_dict.items():
    for bim in ["B3", "B4"]:
        target_2024 = f"{comp}_{bim}_2024"

        if target_2024 not in df.columns:
            print(f"⚠️ No se encontró columna {target_2024}, se omite.")
            continue

        print("=" * 60)
        print(f"   {comp} - {bim}")
        print("=" * 60)

        # Construir features históricos hasta el bimestre anterior
        idx_bim = int(bim[1])
        features_historicas = [f"{f}_B{i}" for f in feats for i in range(1, idx_bim + 1)]

        # ---------------- ENTRENAMIENTO 2024 ----------------
        X_train_2024 = df[[f"{feat}_{year}" for feat in features_historicas for year in ["2021", "2022", "2023"]]]
        y_train_2024 = df[target_2024]

        grid_2024 = GridSearchCV(pipe, param_grid, scoring='f1', cv=cv, n_jobs=-1)
        grid_2024.fit(X_train_2024, y_train_2024)

        # Mejor umbral en 2024
        y_proba_2024 = grid_2024.predict_proba(X_train_2024)[:, 1]
        thresholds = np.linspace(0, 1, 101)
        f1_scores = [f1_score(y_train_2024, (y_proba_2024 >= t).astype(int)) for t in thresholds]
        best_t = thresholds[np.argmax(f1_scores)]

        print("Mejores Hiperparámetros 2024:", grid_2024.best_params_)
        print("Umbral óptimo 2024:", round(best_t, 2))

        # === MATRIZ DE CONFUSIÓN ===
        y_pred_2024 = (y_proba_2024 >= best_t).astype(int)
        cm = confusion_matrix(y_train_2024, y_pred_2024)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
        disp.plot(cmap='Blues', values_format='d')
        plt.title(f"Matriz de confusión {comp}-{bim}-2024")
        plt.show()

        print(f"Matriz de confusión {comp}-{bim}-2024:\n{cm}\n")
        print(classification_report(y_train_2024, y_pred_2024))

        # ---------------- PREDICCIÓN 2025 ----------------
        X_pred_2025 = df[[f"{feat}_{year}" for feat in features_historicas for year in ["2022", "2023", "2024"]]].copy()

        # Renombrar columnas temporalmente para coincidir con X_train_2024
        rename_dict = {}
        for feat in features_historicas:
            rename_dict[f"{feat}_2022"] = f"{feat}_2021"
            rename_dict[f"{feat}_2023"] = f"{feat}_2022"
            rename_dict[f"{feat}_2024"] = f"{feat}_2023"
        X_pred_2025.rename(columns=rename_dict, inplace=True)

        y_proba_2025 = grid_2024.predict_proba(X_pred_2025)[:, 1]
        y_pred_2025 = (y_proba_2025 >= best_t).astype(int)
        df[f"{comp}_{bim}_2025"] = y_pred_2025

        # Métricas sobre 2024
        precision = precision_score(y_train_2024, y_pred_2024)
        recall = recall_score(y_train_2024, y_pred_2024)
        f1 = f1_score(y_train_2024, y_pred_2024)
        acc = accuracy_score(y_train_2024, y_pred_2024)

        resultados.append({
            "Competencia": comp,
            "Bimestre": bim,
            "Mejores_Params": grid_2024.best_params_,
            "Umbral": round(best_t, 2),
            "Accuracy_2024": round(acc, 4),
            "Precision_2024": round(precision, 4),
            "Recall_2024": round(recall, 4),
            "F1_2024": round(f1, 4),
            "MatrizConfusion": cm.tolist()
        })

        print(f"✅ Predicción {comp}-{bim}-2025 generada.\n")

# =======================
# 4. Resumen final
# =======================
df_resultados = pd.DataFrame(resultados)
print("\n===== RESUMEN DE RESULTADOS =====")
print(df_resultados)

# Guardar resultados y predicciones
df.to_csv("/content/DATAMAT012025_SVM_Predicciones2025.csv", index=False)
df_resultados.to_csv("/content/Resultados_SVM_B3B4.csv", index=False)
# Out:
# ...
#    M1 - B3
# ...
# Mejores Hiperparámetros 2024: {'clf__C': 0.1, 'clf__gamma': 'scale', 'clf__kernel': 'poly'}
# Umbral óptimo 2024: 0.54
# Matriz de confusión M1-B3-2024:
# [[23 17]
#  [ 7 44]]
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.57      0.66        40
#            1       0.72      0.86      0.79        51
#
#     accuracy                           0.74        91
#    macro avg       0.74      0.72      0.72        91
# weighted avg       0.74      0.74      0.73        91
#
# ✅ Predicción M1-B3-2025 generada.
#
# ...
#    M1 - B4
# ...
# Mejores Hiperparámetros 2024: {'clf__C': 0.1, 'clf__gamma': 'scale', 'clf__kernel': 'poly'}
# Umbral óptimo 2024: 0.54
# Matriz de confusión M1-B4-2024:
# [[23 17]
#  [ 7 44]]
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.57      0.66        40
#            1       0.72      0.86      0.79        51
#
#     accuracy                           0.74        91
# ...

# %%
LIGHTGBM B1 B2 2024

# %%
# ============================================
# LIGHTGBM - PREDICCIÓN TEMPORAL (M1–M4, B1–B2)
# ============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import (
    classification_report, f1_score, precision_score, recall_score,
    accuracy_score, confusion_matrix, ConfusionMatrixDisplay
)
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline
from lightgbm import LGBMClassifier

# =======================
# 0. Cargar datos
# =======================
df = pd.read_csv("/content/DATAMAT012025.csv")

# =======================
# 1. Definir lógica de features
# =======================
competencias_dict = {
    "M1": ["M1"],
    "M2": ["M1", "M2"],
    "M3": ["M1", "M2", "M3"],
    "M4": ["M1", "M2", "M3", "M4"]
}

bimestres = ["B1", "B2"]

# =======================
# 2. Configuración pipeline
# =======================
pipe = ImbPipeline([
    ('smote', SMOTE(random_state=42)),
    ('clf', LGBMClassifier(random_state=42))
])

param_grid = {
    'clf__n_estimators': [100, 200],
    'clf__max_depth': [-1, 5, 10],
    'clf__learning_rate': [0.05, 0.1, 0.2],
    'clf__num_leaves': [31, 63]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# =======================
# 3. Loop competencias/bimestres
# =======================
resultados = []

for comp, feats in competencias_dict.items():
    for bim in bimestres:

        target_2024 = f"{comp}_{bim}_2024"
        target_2025 = f"{comp}_{bim}_2025"

        # Saltar si no existen targets
        if target_2024 not in df.columns or target_2025 not in df.columns:
            continue

        print("="*60)
        print(f"   {comp} - {bim}")
        print("="*60)

        # Construcción de features dinámicos que existan
        idx_bim = int(bim[1])
        feats_bim = [f"{f}_B{i}" for f in feats for i in range(1, idx_bim+1)]

        # Filtrar solo columnas que existan realmente
        def columnas_existentes(base_feats, years):
            return [
                f"{fb}_{yr}"
                for fb in base_feats
                for yr in years
                if f"{fb}_{yr}" in df.columns
            ]

        cols_train_2024 = columnas_existentes(feats_bim, ["2021", "2022", "2023"])
        cols_train_2025 = columnas_existentes(feats_bim, ["2022", "2023", "2024"])

        # Verificar si hay suficientes columnas
        if len(cols_train_2024) == 0 or len(cols_train_2025) == 0:
            print(" → Saltado por falta de columnas completas.")
            continue

        # ================================
        #  ENTRENAMIENTO PARA VALIDACIÓN 2024
        # ================================
        X_train_2024 = df[cols_train_2024]
        y_train_2024 = df[target_2024]

        grid_2024 = GridSearchCV(pipe, param_grid, scoring='f1', cv=cv, n_jobs=-1)
        grid_2024.fit(X_train_2024, y_train_2024)

        y_proba_2024 = grid_2024.predict_proba(X_train_2024)[:, 1]

        thresholds = np.linspace(0, 1, 101)
        f1_scores = [f1_score(y_train_2024, (y_proba_2024 >= t).astype(int)) for t in thresholds]
        best_t = thresholds[np.argmax(f1_scores)]

        print("Mejores hiperparámetros 2024:", grid_2024.best_params_)
        print("Umbral óptimo 2024:", round(best_t, 2))

        # ================================
        #  ENTRENAMIENTO FINAL → PREDICCIÓN 2025
        # ================================
        X_train_2025 = df[cols_train_2025]
        y_train_2025 = df[target_2025]

        grid_2025 = GridSearchCV(pipe, param_grid, scoring='f1', cv=cv, n_jobs=-1)
        grid_2025.fit(X_train_2025, y_train_2025)

        y_proba_2025 = grid_2025.predict_proba(X_train_2025)[:, 1]
        y_pred_2025 = (y_proba_2025 >= best_t).astype(int)

        # ================================
        #  MÉTRICAS
        # ================================
        precision = precision_score(y_train_2025, y_pred_2025)
        recall = recall_score(y_train_2025, y_pred_2025)
        f1 = f1_score(y_train_2025, y_pred_2025)
        acc = accuracy_score(y_train_2025, y_pred_2025)

        print("\nReporte clasificación 2025:")
        print(classification_report(y_train_2025, y_pred_2025))
        print(f"Aciertos: {(y_pred_2025 == y_train_2025).sum()}, Fallos: {(y_pred_2025 != y_train_2025).sum()}, Exactitud: {acc:.2%}")

        # Matriz de confusión
        cm = confusion_matrix(y_train_2025, y_pred_2025)
        tn, fp, fn, tp = cm.ravel()

        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1])
        disp.plot(cmap=plt.cm.Blues, values_format="d")
        plt.title(f"{comp}-{bim} | Matriz Confusión 2025 (LightGBM)")
        plt.show()

        # Guardar resultados
        resultados.append({
            "Competencia": comp,
            "Bimestre": bim,
            "Mejores_Params": grid_2024.best_params_,
            "Umbral": round(best_t, 2),
            "Accuracy_2025": round(acc, 4),
            "Precision_2025": round(precision, 4),
            "Recall_2025": round(recall, 4),
            "F1_2025": round(f1, 4),
            "TN": int(tn),
            "FP": int(fp),
            "FN": int(fn),
            "TP": int(tp)
        })

# =======================
# 4. Tabla resumen
# =======================
df_resultados = pd.DataFrame(resultados)
print("\n===== RESUMEN DE RESULTADOS =====")
print(df_resultados)
# Out:
# ...
#    M1 - B1
# ...
# [LightGBM] [Info] Number of positive: 51, number of negative: 51
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000038 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6
# [LightGBM] [Info] Number of data points in the train set: 102, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# LIGHT GBM CON B3 Y B4

# %%
# ============================================
# LIGHTGBM - PREDICCIÓN TEMPORAL (M1–M4, B3–B4) PARA 2025
# + MATRICES DE CONFUSIÓN 2024
# ============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline
from lightgbm import LGBMClassifier

# =======================
# 0. Cargar datos
# =======================
df = pd.read_csv("/content/DATAMAT012025.csv")

# =======================
# 1. Definir competencias y bimestres
# =======================
competencias_dict = {
    "M1": ["M1"],
    "M2": ["M1", "M2"],
    "M3": ["M1", "M2", "M3"],
    "M4": ["M1", "M2", "M3", "M4"]
}
bimestres = ["B3", "B4"]  # Solo B3 y B4

# =======================
# 2. Configuración pipeline
# =======================
pipe = ImbPipeline([
    ('smote', SMOTE(random_state=42)),
    ('clf', LGBMClassifier(random_state=42))
])

param_grid = {
    'clf__n_estimators': [100, 200],
    'clf__max_depth': [-1, 5, 10],
    'clf__learning_rate': [0.05, 0.1, 0.2],
    'clf__num_leaves': [31, 63]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# =======================
# 3. Loop competencias/bimestres
# =======================
resultados = []

for comp, feats in competencias_dict.items():
    for bim in bimestres:
        target_2024 = f"{comp}_{bim}_2024"

        if target_2024 not in df.columns:
            print(f"⚠️  No se encontró columna {target_2024}, se omite.")
            continue

        print("="*60)
        print(f"   {comp} - {bim}")
        print("="*60)

        # Construcción de features históricos hasta el bimestre anterior
        idx_bim = int(bim[1])  # B3=3, B4=4
        feats_bim = [f"{f}_B{i}" for f in feats for i in range(1, idx_bim)]

        # Features de entrenamiento (2021–2023 → target 2024)
        X_train_2024 = df[[f"{fb}_{year}" for fb in feats_bim for year in ["2021","2022","2023"]]]
        y_train_2024 = df[target_2024]

        # GridSearchCV para encontrar mejores hiperparámetros
        grid_2024 = GridSearchCV(pipe, param_grid, scoring='f1', cv=cv, n_jobs=-1)
        grid_2024.fit(X_train_2024, y_train_2024)

        # Ajuste de umbral óptimo en 2024
        y_proba_2024 = grid_2024.predict_proba(X_train_2024)[:,1]
        thresholds = np.linspace(0,1,101)
        f1_scores = [f1_score(y_train_2024, (y_proba_2024 >= t).astype(int)) for t in thresholds]
        best_t = thresholds[np.argmax(f1_scores)]

        y_pred_2024 = (y_proba_2024 >= best_t).astype(int)

        print("Mejores hiperparámetros:", grid_2024.best_params_)
        print("Umbral óptimo:", round(best_t,2))
        print("\n--- Métricas 2024 ---")
        print(classification_report(y_train_2024, y_pred_2024))

        # === MATRIZ DE CONFUSIÓN 2024 ===
        cm = confusion_matrix(y_train_2024, y_pred_2024)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1])
        disp.plot(cmap='Blues', values_format='d')
        plt.title(f"Matriz de confusión {comp}-{bim}-2024")
        plt.show()

        # =======================
        # Predicción para 2025
        # =======================
        # Features: 2022–2024
        X_pred_2025 = df[[f"{fb}_{year}" for fb in feats_bim for year in ["2022","2023","2024"]]]
        y_proba_2025 = grid_2024.predict_proba(X_pred_2025)[:,1]
        y_pred_2025 = (y_proba_2025 >= best_t).astype(int)

        # Guardar predicciones como nueva columna
        df[f"{comp}_{bim}_2025"] = y_pred_2025

        # Métricas sobre 2024
        precision = precision_score(y_train_2024, y_pred_2024)
        recall = recall_score(y_train_2024, y_pred_2024)
        f1 = f1_score(y_train_2024, y_pred_2024)
        acc = accuracy_score(y_train_2024, y_pred_2024)

        resultados.append({
            "Competencia": comp,
            "Bimestre": bim,
            "Mejores_Params": grid_2024.best_params_,
            "Umbral": round(best_t,2),
            "Accuracy_2024": round(acc,4),
            "Precision_2024": round(precision,4),
            "Recall_2024": round(recall,4),
            "F1_2024": round(f1,4),
            "MatrizConfusion_2024": cm.tolist()
        })

        print(f"✅ Predicción {comp}-{bim}-2025 generada.\n")

# =======================
# 4. Resumen y exportación
# =======================
df_resultados = pd.DataFrame(resultados)
print("\n===== RESUMEN DE RESULTADOS =====")
print(df_resultados)

# Guardar resultados y predicciones
df.to_csv("/content/DATAMAT012025_Predicciones2025_LightGBM.csv", index=False)
df_resultados.to_csv("/content/Resultados_LightGBM_B3B4.csv", index=False)
# Out:
# ...
#    M1 - B3
# ...
# [LightGBM] [Info] Number of positive: 51, number of negative: 51
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000051 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12
# [LightGBM] [Info] Number of data points in the train set: 102, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
GRAFICOS ROC AUC

# %%
from sklearn.metrics import roc_curve, auc
import seaborn as sns

# =======================
# Curva ROC / AUC para 2024
# =======================
fpr, tpr, thresholds_roc = roc_curve(y_train_2024, y_proba_2024)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0,1], [0,1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC - {comp}-{bim}-2024')
plt.legend(loc="lower right")
plt.show()

# %%
# =======================
# Curva de importancia de features LightGBM
# =======================
clf_best = grid_2024.best_estimator_.named_steps['clf']
importances = clf_best.feature_importances_
feat_names = X_train_2024.columns

feat_imp_df = pd.DataFrame({
    'Feature': feat_names,
    'Importancia': importances
}).sort_values(by='Importancia', ascending=False)

plt.figure(figsize=(8,6))
sns.barplot(x='Importancia', y='Feature', data=feat_imp_df.head(20), palette='viridis')
plt.title(f'Importancia Features - {comp}-{bim}-2024')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2933258097.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importancia', y='Feature', data=feat_imp_df.head(20), palette='viridis')

# %%
# ============================================
# LIGHTGBM - PREDICCIÓN TEMPORAL (M1–M4, B3–B4) PARA 2025 + ROC/AUC + Importancia Features
# ============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import (
    f1_score, precision_score, recall_score, accuracy_score,
    roc_curve, auc
)
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline
from lightgbm import LGBMClassifier

# =======================
# 0. Cargar datos
# =======================
df = pd.read_csv("/content/DATAMAT012025.csv")

# =======================
# 1. Definir competencias y bimestres
# =======================
competencias_dict = {
    "M1": ["M1"],
    "M2": ["M1", "M2"],
    "M3": ["M1", "M2", "M3"],
    "M4": ["M1", "M2", "M3", "M4"]
}
bimestres = ["B3", "B4"]  # Solo B3 y B4

# =======================
# 2. Configuración pipeline
# =======================
pipe = ImbPipeline([
    ('smote', SMOTE(random_state=42)),
    ('clf', LGBMClassifier(random_state=42))
])

param_grid = {
    'clf__n_estimators': [100, 200],
    'clf__max_depth': [-1, 5, 10],
    'clf__learning_rate': [0.05, 0.1, 0.2],
    'clf__num_leaves': [31, 63]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# =======================
# 3. Loop competencias/bimestres
# =======================
resultados = []

for comp, feats in competencias_dict.items():
    for bim in bimestres:
        target_2024 = f"{comp}_{bim}_2024"

        if target_2024 not in df.columns:
            print(f"⚠️  No se encontró columna {target_2024}, se omite.")
            continue

        print("="*60)
        print(f"   {comp} - {bim}")
        print("="*60)

        # Construcción de features
        idx_bim = int(bim[1])  # B3=3, B4=4
        feats_bim = [f"{f}_B{i}" for f in feats for i in range(1, idx_bim+1)]

        # =======================
        # ENTRENAMIENTO PARA 2024
        # =======================
        X_train_2024 = df[[f"{fb}_{year}" for fb in feats_bim for year in ["2021","2022","2023"]]]
        y_train_2024 = df[target_2024]

        grid_2024 = GridSearchCV(pipe, param_grid, scoring='f1', cv=cv, n_jobs=-1)
        grid_2024.fit(X_train_2024, y_train_2024)

        # Ajuste de umbral óptimo
        y_proba_2024 = grid_2024.predict_proba(X_train_2024)[:,1]
        thresholds = np.linspace(0,1,101)
        f1_scores = [f1_score(y_train_2024, (y_proba_2024 >= t).astype(int)) for t in thresholds]
        best_t = thresholds[np.argmax(f1_scores)]

        print("Mejores hiperparámetros:", grid_2024.best_params_)
        print("Umbral óptimo:", round(best_t,2))

        # =======================
        # Curva ROC / AUC 2024
        # =======================
        fpr, tpr, _ = roc_curve(y_train_2024, y_proba_2024)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(6,5))
        plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
        plt.plot([0,1], [0,1], color='red', lw=2, linestyle='--')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(f'ROC - {comp}-{bim}-2024')
        plt.legend(loc="lower right")
        plt.show()

        # =======================
        # Importancia de features LightGBM
        # =======================
        clf_best = grid_2024.best_estimator_.named_steps['clf']
        importances = clf_best.feature_importances_
        feat_names = X_train_2024.columns

        feat_imp_df = pd.DataFrame({
            'Feature': feat_names,
            'Importancia': importances
        }).sort_values(by='Importancia', ascending=False)

        plt.figure(figsize=(8,6))
        sns.barplot(x='Importancia', y='Feature', data=feat_imp_df.head(20), palette='viridis')
        plt.title(f'Importancia Features - {comp}-{bim}-2024')
        plt.tight_layout()
        plt.show()

        # =======================
        # Predicción para 2025
        # =======================
        X_pred_2025 = df[[f"{fb}_{year}" for fb in feats_bim for year in ["2022","2023","2024"]]]
        y_proba_2025 = grid_2024.predict_proba(X_pred_2025)[:,1]
        y_pred_2025 = (y_proba_2025 >= best_t).astype(int)
        df[f"{comp}_{bim}_2025"] = y_pred_2025

        # Métricas sobre 2024 (opcional)
        precision = precision_score(y_train_2024, (y_proba_2024 >= best_t).astype(int))
        recall = recall_score(y_train_2024, (y_proba_2024 >= best_t).astype(int))
        f1 = f1_score(y_train_2024, (y_proba_2024 >= best_t).astype(int))
        acc = accuracy_score(y_train_2024, (y_proba_2024 >= best_t).astype(int))

        resultados.append({
            "Competencia": comp,
            "Bimestre": bim,
            "Mejores_Params": grid_2024.best_params_,
            "Umbral": round(best_t,2),
            "Accuracy_2024": round(acc,4),
            "Precision_2024": round(precision,4),
            "Recall_2024": round(recall,4),
            "F1_2024": round(f1,4)
        })

        print(f"✅ Predicción {comp}-{bim}-2025 generada.\n")

# =======================
# 4. Resumen y exportación
# =======================
df_resultados = pd.DataFrame(resultados)
print("\n===== RESUMEN DE RESULTADOS =====")
print(df_resultados)

# Guardar resultados y predicciones
df.to_csv("/content/DATAMAT012025_Predicciones2025.csv", index=False)
df_resultados.to_csv("/content/Resultados_LightGBM_B3B4.csv", index=False)
# Out:
# ...
#    M1 - B3
# ...
# [LightGBM] [Info] Number of positive: 51, number of negative: 51
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000045 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18
# [LightGBM] [Info] Number of data points in the train set: 102, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
